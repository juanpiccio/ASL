# %% [markdown]
# # CML II - Project - Custom Training with YOLOv5
#
# Iván Aguilar & Juan Picciotti
#
# This notebook is very basic since it is only employed for training purposes:
# - We install the requirements and import the modules.
# - Then we upload to the session all the pertinent files:
#   - Train and validations sets.
#   - Configuration files .yaml which contain information on where the data is stored, how many and what the labels are, hyperparameters, etc.
#   - Pretrained weights.
#
# For more details on these, please see the main document for this project.
#
# Then we run the training script provided by YOLOv5, and once it is finished, we download the weights to do detecting in another notebook.

# %% [markdown]
# ## Install Requirements

# %%
#clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 11335, done.
# remote: Total 11335 (delta 0), reused 0 (delta 0), pack-reused 11335
# Receiving objects: 100% (11335/11335), 11.16 MiB | 15.66 MiB/s, done.
# Resolving deltas: 100% (7842/7842), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 5.7 MB/s
#      |████████████████████████████████| 1.1 MB 7.5 MB/s
#      |████████████████████████████████| 145 kB 33.1 MB/s
#      |████████████████████████████████| 138 kB 44.6 MB/s
#      |████████████████████████████████| 67 kB 5.3 MB/s
#      |████████████████████████████████| 178 kB 45.1 MB/s
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# ...

# %% [markdown]
# Train Our Custom YOLOv5 model
#
# This uses the data loaded to the session.
#
# We pass a number of arguments which are detailedly explain in the main document.

# %%
# !python train.py --img 320 --cfg yolov5_26classes.yaml --hyp hyp.scratch-med.yaml --batch 32 --epochs 150 --data colab.yaml --weights yolov5s.pt --workers 24 --name colab_asl
# Out:
# ...
# train: weights=yolov5s.pt, cfg=yolov5_26classes.yaml, data=colab.yaml, hyp=hyp.scratch-med.yaml, epochs=150, batch_size=32, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=24, project=runs/train, name=colab_asl, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-36-gc09fb2a torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# Once the training is finished, we download the weights.

# %%
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')
